# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
wscjtc = pd.read_csv('/Users/marcolaureano2/Documents/GitHub/WSCJTC/Data/Washington_State_Criminal_Justice_Training_Commission_Officer_Certification_Cases_20231116.csv')

# %%
wscjtc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Case #                   880 non-null    object
#  1   Officer Name             880 non-null    object
#  2   Employer                 868 non-null    object
#  3   Agency Type              866 non-null    object
#  4   Certification Type       878 non-null    object
#  5   Status                   880 non-null    object
#  6   Reason for Opening Case  879 non-null    object
#  7   Conduct Investigated     660 non-null    object
#  8   Case Determination       620 non-null    object
#  9   Date Received            880 non-null    object
#  10  Under Review             682 non-null    object
#  11  Statement of Charges     367 non-null    object
#  12  Hearing                  91 non-null     object
#  13  Final Order              356 non-null    object
# ...

# %%
wscjtc
# Out:
#       Case #         Officer Name                                Employer  \
# 0     23-604     Whelan, Lawrence  Steilacoom Department of Public Safety
# 1     23-589            Yabe, Tom  Steilacoom Department of Public Safety
# 2     23-577  Hilton, Clay Vaughn         Spokane County Sheriff's Office
# 3     23-571       Cantu, Leandro          Benton County Sheriff's Office
# 4     23-572             Law, Jon          Benton County Sheriff's Office
# ..       ...                  ...                                     ...
# 875   23-117    Robinson, Cleades                              Seattle PD
# 876   23-634        Okeefe, Brady                              Seattle PD
# 877  R22-055       Szalda, Nathan                             Lynnwood PD
# 878  R22-056       Noble, Douglas                             Lynnwood PD
# 879   23-663      Harding, Ronald                              Poulsbo PD
#
#     Agency Type Certification Type         Status Reason for Opening Case  \
# ...

# %%
wscjtc.columns
# Out:
# Index(['Case #', 'Officer Name', 'Employer', 'Agency Type',
#        'Certification Type', 'Status', 'Reason for Opening Case',
#        'Conduct Investigated', 'Case Determination', 'Date Received',
#        'Under Review', 'Statement of Charges', 'Hearing', 'Final Order',
#        'Date Closed', 'Documents Link'],
#       dtype='object')

# %%
wscjtc = wscjtc.set_index('Case #')

# %%
wscjtc
# Out:
#                 Officer Name                                Employer  \
# Case #
# 23-604      Whelan, Lawrence  Steilacoom Department of Public Safety
# 23-589             Yabe, Tom  Steilacoom Department of Public Safety
# 23-577   Hilton, Clay Vaughn         Spokane County Sheriff's Office
# 23-571        Cantu, Leandro          Benton County Sheriff's Office
# 23-572              Law, Jon          Benton County Sheriff's Office
# ...                      ...                                     ...
# 23-117     Robinson, Cleades                              Seattle PD
# 23-634         Okeefe, Brady                              Seattle PD
# R22-055       Szalda, Nathan                             Lynnwood PD
# R22-056       Noble, Douglas                             Lynnwood PD
# 23-663       Harding, Ronald                              Poulsbo PD
#
#         Agency Type Certification Type         Status Reason for Opening Case  \
# Case #
# ...

# %%
wscjtc['Employer'].unique()
# Out:
# array(['Steilacoom Department of Public Safety',
#        "Spokane County Sheriff's Office",
#        "Benton County Sheriff's Office",
#        "Snohomish County Sheriff's Office", 'Coulee Dam PD',
#        'Grand Coulee PD', 'Kennewick PD', 'Toledo PD', 'Everett PD',
#        'Seattle PD', 'Bellingham PD', 'Kittitas PD', 'Pasco PD',
#        'Goldendale PD', 'Centralia PD',
#        "Columbia County Sheriff's Office",
#        "Skamania County Sheriff's Office", 'Mabton PD',
#        "King County Sheriff's Office", 'Bellevue PD', 'Spokane PD',
#        'Lake Stevens PD', "Clark County Sheriff's Office", 'Lacey PD',
#        "Whatcom County Sheriff's Office",
#        'King County Department of Adult & Juvenile Detention',
#        'Kalispel Tribal Public Safety',
#        "Okanogan County Sheriff's Office", 'Yakima PD',
#        "Lewis County Sheriff's Office", 'Granger PD', 'Kent PD',
#        'Lakewood PD', 'Richland PD', 'Spokane County Detention Services',
# ...

# %%
wscjtc['Employer'].value_counts()
# Out:
# Seattle PD                           57
# King County Sheriff's Office         55
# WA State Patrol                      34
# Pierce County Sheriff's Office       25
# Snohomish County Sheriff's Office    23
#                                      ..
# Reardan PD                            1
# Coulee Dam PD                         1
# Puyallup Tribal PD                    1
# Battle Ground PD                      1
# Mercer Island PD                      1
# Name: Employer, Length: 189, dtype: int64

# %% [markdown]
# The top 3 agencies with complaints are Seattle Police, King County Sherrif's Office, and Washington State Patrol

# %%
seattle_filter = wscjtc['Employer'] == 'Seattle PD'

# %%
seattle = wscjtc[seattle_filter]
seattle
# Out:
#                     Officer Name    Employer Agency Type Certification Type  \
# Case #
# 23-491           Auderer, Daniel  Seattle PD          PD      Peace Officer
# 23-421               David Adams  Seattle PD          PD      Peace Officer
# 23-339            Gandy, Brandon  Seattle PD          PD      Peace Officer
# 23-184         Ojeda Lopez, Rosa  Seattle PD          PD      Peace Officer
# 22-068        Constantin, Andrei  Seattle PD          PD      Peace Officer
# C22-049       Fitzgerald, Ashley  Seattle PD          PD      Peace Officer
# C22-042       Fitzgerald, Ashley  Seattle PD          PD      Peace Officer
# C22-031       Fitzgerald, Ashley  Seattle PD          PD      Peace Officer
# C22-030       Fitzgerald, Ashley  Seattle PD          PD      Peace Officer
# 21-042        Everett, Alexander  Seattle PD          PD      Peace Officer
# 21-043          Everett, Caitlin  Seattle PD          PD      Peace Officer
# ...

# %%
kcso_filter = wscjtc['Employer'] == "King County Sheriff's Office"

# %%
kcso = wscjtc[kcso_filter]
kcso
# Out:
#                   Officer Name                      Employer Agency Type  \
# Case #
# 23-430             Riess, Ryan  King County Sheriff's Office     Sheriff
# 23-394         Alvarez, George  King County Sheriff's Office     Sheriff
# 23-371            Abbott, Ryan  King County Sheriff's Office     Sheriff
# 23-262            Volk, Michel  King County Sheriff's Office     Sheriff
# 23-181           Chavez, Jason  King County Sheriff's Office     Sheriff
# 23-109           Good, Matthew  King County Sheriff's Office     Sheriff
# R22-145          Brent, Ernest  King County Sheriff's Office     Sheriff
# R22-026           Jarrett, Job  King County Sheriff's Office     Sheriff
# 21-065          Tilton, Andrew  King County Sheriff's Office     Sheriff
# R21-036          Davis, Joshua  King County Sheriff's Office     Sheriff
# 21-049          Malloy, Daniel  King County Sheriff's Office     Sheriff
# 21-047           Bailey, Jessy  King County Sheriff's Office     Sheriff
# ...

# %%
wasp_filter = wscjtc['Employer'] == 'WA State Patrol'

# %%
wasp = wscjtc[wasp_filter]
wasp
# Out:
#                    Officer Name         Employer Agency Type  \
# Case #
# 23-337           Leach, Mckenzy  WA State Patrol       State
# 23-305        Cozzitorto, Peter  WA State Patrol       State
# 23-113            Arnold, James  WA State Patrol       State
# 23-057          Whales, Timothy  WA State Patrol       State
# 23-021              Lewis, Mark  WA State Patrol       State
# R22-172            Heath, Woody  WA State Patrol       State
# C22-032           Batiste, John  WA State Patrol       State
# 22-023          Burress, Thomas  WA State Patrol       State
# C22-004           Batiste, John  WA State Patrol       State
# 21-018             Meenan, Sean  WA State Patrol       State
# 21-002              Jones, Seth  WA State Patrol       State
# 20-796             Carr, Sean M  WA State Patrol       State
# 19-765        Woods, Reginald J  WA State Patrol       State
# 19-741          Coons, Austin M  WA State Patrol       State
# ...

# %%
wscjtc['Reason for Opening Case'].value_counts()
# Out:
# Agency Report                672
# Complaint                    185
# Division Initiated            10
# Request for Reinstatement     10
# Other                          2
# Name: Reason for Opening Case, dtype: int64

# %%
wscjtc['Conduct Investigated'].value_counts()
# Out:
# RCW 43.101.105(2)(d)         230
# Other                        110
# RCW 43.101.105(2)(a)          77
# RCW 43.101.105(3)(e)          43
# RCW 43.101.105(2)(e)          38
# RCW 43.101.105(3)(k)          28
# RCW 9A.80.010                 28
# RCW 43.101.105(3)(j)(iv)      26
# RCW 42.20.100                 19
# RCW 43.101.105(3)(h)          12
# RCW 43.101.105(3)(i)           8
# RCW 43.101.105(3)(a)           8
# RCW 43.101.105(3)(g)           7
# RCW 43.101.105(3)(l)           7
# RCW 43.101.105(3)(f)           5
# RCW 43.101.105(3)(j)(iii)      4
# RCW 43.101.105(3)(j)(i)        3
# RCW 43.101.105(3)(j)(ii)       2
# RCW 43.101.105(3)(c)           1
# 43.101.105(3)(e)               1
# 43.101.105(3)(g)               1
# RCW 9A.76.175                  1
# RCW 43.101.105(3)(b)           1
# Name: Conduct Investigated, dtype: int64

# %% [markdown]
# The most common conduct investigated is RCW 43.101.105(2)(d)
#
# RCW 43.101.105(2)(d)
# - Has been terminated by the employing agency or otherwise separated from the employing agency after knowingly making, or found by a court to have knowingly made, misleading, deceptive, untrue, or fraudulent representations in the practice of being a peace officer or corrections officer including, but not limited to, committing perjury, filing false reports, hiding evidence, or failing to report exonerating information. This subsection (2)(d) does not apply to representations made in the course and for the purposes of an undercover investigation or other lawful law enforcement purpose.

# %%
seattle['Conduct Investigated'].value_counts()
# Out:
# RCW 43.101.105(2)(d)        14
# Other                       12
# RCW 43.101.105(2)(a)         7
# RCW 9A.80.010                3
# RCW 43.101.105(3)(h)         2
# RCW 43.101.105(3)(j)(iv)     2
# RCW 43.101.105(3)(g)         2
# RCW 43.101.105(3)(k)         2
# RCW 43.101.105(3)(e)         1
# Name: Conduct Investigated, dtype: int64

# %%
kcso['Conduct Investigated'].value_counts()
# Out:
# RCW 43.101.105(2)(d)        17
# RCW 43.101.105(2)(a)         6
# RCW 43.101.105(3)(e)         3
# RCW 9A.80.010                3
# RCW 43.101.105(2)(e)         3
# Other                        2
# RCW 43.101.105(3)(i)         1
# RCW 43.101.105(3)(f)         1
# RCW 43.101.105(3)(h)         1
# RCW 43.101.105(3)(g)         1
# RCW 43.101.105(3)(j)(iv)     1
# RCW 43.101.105(3)(a)         1
# RCW 43.101.105(3)(k)         1
# Name: Conduct Investigated, dtype: int64

# %%
wasp['Conduct Investigated'].value_counts()
# Out:
# RCW 43.101.105(2)(d)        8
# RCW 43.101.105(2)(a)        3
# RCW 43.101.105(3)(e)        2
# Other                       2
# RCW 43.101.105(2)(e)        2
# RCW 9A.80.010               2
# RCW 43.101.105(3)(a)        2
# RCW 43.101.105(3)(k)        2
# RCW 43.101.105(3)(i)        1
# RCW 42.20.100               1
# RCW 43.101.105(3)(j)(iv)    1
# Name: Conduct Investigated, dtype: int64

# %%
seattle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57 entries, 23-491 to 23-634
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Officer Name             57 non-null     object
#  1   Employer                 57 non-null     object
#  2   Agency Type              57 non-null     object
#  3   Certification Type       57 non-null     object
#  4   Status                   57 non-null     object
#  5   Reason for Opening Case  57 non-null     object
#  6   Conduct Investigated     45 non-null     object
#  7   Case Determination       41 non-null     object
#  8   Date Received            57 non-null     object
#  9   Under Review             41 non-null     object
#  10  Statement of Charges     24 non-null     object
#  11  Hearing                  3 non-null      object
#  12  Final Order              25 non-null     object
#  13  Date Closed              41 non-null     object
# ...

# %%
kcso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55 entries, 23-430 to 23-168
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Officer Name             55 non-null     object
#  1   Employer                 55 non-null     object
#  2   Agency Type              55 non-null     object
#  3   Certification Type       55 non-null     object
#  4   Status                   55 non-null     object
#  5   Reason for Opening Case  55 non-null     object
#  6   Conduct Investigated     41 non-null     object
#  7   Case Determination       42 non-null     object
#  8   Date Received            55 non-null     object
#  9   Under Review             41 non-null     object
#  10  Statement of Charges     32 non-null     object
#  11  Hearing                  2 non-null      object
#  12  Final Order              28 non-null     object
#  13  Date Closed              42 non-null     object
# ...

# %%
wasp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 23-337 to 03-036
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Officer Name             34 non-null     object
#  1   Employer                 34 non-null     object
#  2   Agency Type              34 non-null     object
#  3   Certification Type       34 non-null     object
#  4   Status                   34 non-null     object
#  5   Reason for Opening Case  34 non-null     object
#  6   Conduct Investigated     26 non-null     object
#  7   Case Determination       26 non-null     object
#  8   Date Received            34 non-null     object
#  9   Under Review             22 non-null     object
#  10  Statement of Charges     13 non-null     object
#  11  Hearing                  3 non-null      object
#  12  Final Order              13 non-null     object
#  13  Date Closed              26 non-null     object
# ...

# %%
wasp.head()
# Out:
#              Officer Name         Employer Agency Type Certification Type  \
# Case #
# 23-337     Leach, Mckenzy  WA State Patrol       State      Peace Officer
# 23-305  Cozzitorto, Peter  WA State Patrol       State      Peace Officer
# 23-113      Arnold, James  WA State Patrol       State      Peace Officer
# 23-057    Whales, Timothy  WA State Patrol       State      Peace Officer
# 23-021        Lewis, Mark  WA State Patrol       State      Peace Officer
#
#                Status Reason for Opening Case  Conduct Investigated  \
# Case #
# 23-337  Investigation           Agency Report  RCW 43.101.105(3)(e)
# 23-305  Investigation           Agency Report                   NaN
# 23-113  Investigation           Agency Report                   NaN
# 23-057         Closed               Complaint  RCW 43.101.105(3)(e)
# 23-021  Investigation      Division Initiated                 Other
#
#        Case Determination Date Received Under Review Statement of Charges  \
# Case #
# ...

# %%
kcso.head()
# Out:
#            Officer Name                      Employer Agency Type  \
# Case #
# 23-430      Riess, Ryan  King County Sheriff's Office     Sheriff
# 23-394  Alvarez, George  King County Sheriff's Office     Sheriff
# 23-371     Abbott, Ryan  King County Sheriff's Office     Sheriff
# 23-262     Volk, Michel  King County Sheriff's Office     Sheriff
# 23-181    Chavez, Jason  King County Sheriff's Office     Sheriff
#
#        Certification Type         Status Reason for Opening Case  \
# Case #
# 23-430      Peace Officer  Investigation           Agency Report
# 23-394      Peace Officer  Investigation               Complaint
# 23-371      Peace Officer  Investigation           Agency Report
# 23-262      Peace Officer  Investigation           Agency Report
# 23-181      Peace Officer  Investigation           Agency Report
#
#        Conduct Investigated Case Determination Date Received Under Review  \
# Case #
# ...

# %%
wasp.tail()
# Out:
#                Officer Name         Employer Agency Type Certification Type  \
# Case #
# 15-584  Fournier, Justin S.  WA State Patrol       State      Peace Officer
# 09-334         Barnes, Gary  WA State Patrol       State      Peace Officer
# 08-234    Torres, Carlos M.  WA State Patrol       State      Peace Officer
# 05-111      Idland, Michael  WA State Patrol       State      Peace Officer
# 03-036        Sholtys, Mark  WA State Patrol       State      Peace Officer
#
#         Status Reason for Opening Case  Conduct Investigated  \
# Case #
# 15-584  Closed           Agency Report  RCW 43.101.105(2)(d)
# 09-334  Closed           Agency Report         RCW 9A.80.010
# 08-234  Closed           Agency Report  RCW 43.101.105(2)(a)
# 05-111  Closed           Agency Report  RCW 43.101.105(2)(a)
# 03-036  Closed           Agency Report  RCW 43.101.105(2)(e)
#
#            Case Determination Date Received Under Review Statement of Charges  \
# Case #
# ...
